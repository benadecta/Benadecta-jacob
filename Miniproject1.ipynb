# %% [markdown]
# <a href="https://colab.research.google.com/github/benadecta/Benadecta-jacob/blob/main/Miniproject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
#from sklearn.datasets import load_boston
#df=load_boston()
from sklearn.datasets import fetch_california_housing
df = fetch_california_housing()

# %%
df.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
boston=pd.DataFrame(df.data,columns=df.feature_names)
boston.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
boston['MEDV']=df.target
boston.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude   MEDV
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
boston.isnull()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0       False     False     False      False       False     False     False
# 1       False     False     False      False       False     False     False
# 2       False     False     False      False       False     False     False
# 3       False     False     False      False       False     False     False
# 4       False     False     False      False       False     False     False
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635   False     False     False      False       False     False     False
# 20636   False     False     False      False       False     False     False
# 20637   False     False     False      False       False     False     False
# 20638   False     False     False      False       False     False     False
# 20639   False     False     False      False       False     False     False
#
#        Longitude   MEDV
# ...

# %%
boston.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# MEDV          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X=boston.drop('MEDV', axis=1)
Y=boston['MEDV']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15,random_state=5)

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_train.shape)
# Out:
# (17544, 8)
# (3096, 8)
# (17544,)
# (17544,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
lin_model = LinearRegression()

lin_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train,y_train_predict)))

print("The model performance for training set")
print('RMSE is {}'.format(rmse))
print("/n")

y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test,y_test_predict)))

print("The model performance for testing set")
print('RMSE IS {}'.format(rmse))
# Out:
# The model performance for training set
# RMSE is 0.7213386163019015
# /n
# The model performance for testing set
# RMSE IS 0.7398122005751494

# %%
f1=open("first.txt","w")
f1.write("Hello xxx "+"how are you"+"\n"+"i am fine"+"\n ben is cute")
f1.close()

# %%
f1=open("first.txt","r")
str=f1.read()
print(str)
f1.close()
# Out:
# Hello xxx how are you
# i am fine
#  ben is cute

# %%
f1=open("first.txt","r")
str=f1.readline()
print(str)
f1.close()
# Out:
# Hello xxx how are you
